# %%
import pandas as pd
air_quality = pd.read_csv('data/air_quality_no2.csv', engine='python')
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.4, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.area(figsize=(12,8), subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)
